# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, train_test_split

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
test.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00419637202311204720264      6  3020  70.186855   73  Male     Ex-smoker
# 1  ID00421637202311550012437     15  2739  82.045291   68  Male     Ex-smoker
# 2  ID00422637202311677017371      6  1930  76.672493   73  Male     Ex-smoker
# 3  ID00423637202312137826377     17  3294  79.258903   72  Male     Ex-smoker
# 4  ID00426637202313170790466      0  2925  71.824968   73  Male  Never smoked

# %%
train.head()
# Out:
#                      Patient  Weeks   FVC    Percent  Age   Sex SmokingStatus
# 0  ID00007637202177411956430     -4  2315  58.253649   79  Male     Ex-smoker
# 1  ID00007637202177411956430      5  2214  55.712129   79  Male     Ex-smoker
# 2  ID00007637202177411956430      7  2061  51.862104   79  Male     Ex-smoker
# 3  ID00007637202177411956430      9  2144  53.950679   79  Male     Ex-smoker
# 4  ID00007637202177411956430     11  2069  52.063412   79  Male     Ex-smoker

# %%
train.dtypes
# Out:
# Patient           object
# Weeks              int64
# FVC                int64
# Percent          float64
# Age                int64
# Sex               object
# SmokingStatus     object
# dtype: object

# %%
test.isnull().sum()
# Out:
# Patient          0
# Weeks            0
# FVC              0
# Percent          0
# Age              0
# Sex              0
# SmokingStatus    0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# Patient          0
# Weeks            0
# FVC              0
# Percent          0
# Age              0
# Sex              0
# SmokingStatus    0
# dtype: int64

# %%
train_drop = train.drop(columns=['Patient']).copy()
train_dummies = pd.get_dummies(train_drop, columns=['Sex','SmokingStatus'])
train_dummies
# Out:
#       Weeks   FVC    Percent  Age  Sex_Female  Sex_Male  \
# 0        -4  2315  58.253649   79           0         1
# 1         5  2214  55.712129   79           0         1
# 2         7  2061  51.862104   79           0         1
# 3         9  2144  53.950679   79           0         1
# 4        11  2069  52.063412   79           0         1
# ...     ...   ...        ...  ...         ...       ...
# 1544     13  2712  66.594637   73           0         1
# 1545     19  2978  73.126412   73           0         1
# 1546     31  2908  71.407524   73           0         1
# 1547     43  2975  73.052745   73           0         1
# 1548     59  2774  68.117081   73           0         1
#
#       SmokingStatus_Currently smokes  SmokingStatus_Ex-smoker  \
# 0                                  0                        1
# 1                                  0                        1
# 2                                  0                        1
# 3                                  0                        1
# 4                                  0                        1
# ...                              ...                      ...
# 1544                               0                        0
# 1545                               0                        0
# 1546                               0                        0
# 1547                               0                        0
# 1548                               0                        0
#
#       SmokingStatus_Never smoked
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 1544                           1
# 1545                           1
# 1546                           1
# 1547                           1
# 1548                           1
#
# [1549 rows x 9 columns]

# %%
X = train_dummies.drop('FVC', axis = 1)
y = train_dummies.FVC

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clasif = RandomForestClassifier(n_jobs=2, random_state=0)
clasif.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-41-dc9cca5359a1> in <module>
#       1 clasif = RandomForestClassifier(n_jobs=2, random_state=0)
# ----> 2 clasif.fit(X, y)
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\joblib\parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\multiprocessing\pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\multiprocessing\pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\joblib\_parallel_backends.py in __call__(self, *args, **kwargs)
#     593     def __call__(self, *args, **kwargs):
#     594         try:
# --> 595             return self.func(*args, **kwargs)
#     596         except KeyboardInterrupt as e:
#     597             # We capture the KeyboardInterrupt and reraise it as
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# c:\users\efrain\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._add_node()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._resize_c()
#
# sklearn\tree\_utils.pyx in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 19693568 bytes
